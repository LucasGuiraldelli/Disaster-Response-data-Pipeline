# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import nltk
import pandas as pd
import re
import pickle

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

from nltk.stem import WordNetLemmatizer
from sqlalchemy import create_engine
from nltk.corpus import stopwords
from nltk import word_tokenize

from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, AdaBoostClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 2
#       1 # import libraries
# ----> 2 import nltk
#       3 import pandas as pd
#       4 import re
#
# ModuleNotFoundError: No module named 'nltk'

# %%
# load data from database
engine = create_engine('sqlite:///InsertDatabaseName.db')
df = pd.read_sql_table('disaster_messages', engine)

# %%
x = df['message']
y = df.iloc[:,4:]

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    '''
        normalize, tokenizing, lemmatizing and removing stop words
        
        text: input the text
    '''
    
    text    = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # normalize text
    words   = word_tokenize(text) # tokenizing text
    lemmed  = [WordNetLemmatizer().lemmatize(w) for w in words] # lemmatize
    words   = [w for w in words if w not in stopwords.words("english")] # removing stop words
    
    return words

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
        ('features', FeatureUnion([

            ('text_pipeline', Pipeline([
                ('count_vectorizer', CountVectorizer(tokenizer=tokenize)),
                ('tfidf_transformer', TfidfTransformer())
            ]))
            
        ])),

        ('classifier', MultiOutputClassifier(AdaBoostClassifier()))
    ])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y)

pipeline_fit = pipeline.fit(X_train, y_train)

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
y_prediction_train = pipeline_fit.predict(X_train)
y_prediction_test = pipeline_fit.predict(X_test)

# %%
df.columns

# %%
category_names = list(df.columns[4:])

for i in range(len(category_names)):
        print("Category:", category_names[i],"\n", classification_report(y_test.iloc[:, i].values, y_prediction_test[:, i]))
        print('Accuracy of %25s: %.2f' %(category_names[i], accuracy_score(y_prediction_test[:, i], y_prediction_test[:,i])))
# Out:
# Category: related
#               precision    recall  f1-score   support
#
#           0       0.64      0.14      0.22      1544
#           1       0.78      0.97      0.87      4963
#           2       0.19      0.06      0.10        47
#
# avg / total       0.74      0.77      0.71      6554
#
# Accuracy of                   related: 1.00
# Category: request
#               precision    recall  f1-score   support
#
#           0       0.90      0.97      0.93      5420
#           1       0.76      0.51      0.61      1134
#
# avg / total       0.88      0.89      0.88      6554
#
# Accuracy of                   request: 1.00
# Category: offer
#               precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6526
#           1       0.00      0.00      0.00        28
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy of                     offer: 1.00
# Category: aid_related
#               precision    recall  f1-score   support
#
#           0       0.74      0.87      0.80      3858
#           1       0.75      0.57      0.65      2696
#
# avg / total       0.75      0.75      0.74      6554
#
# Accuracy of               aid_related: 1.00
# Category: medical_help
#               precision    recall  f1-score   support
#
#           0       0.95      0.98      0.96      6074
#           1       0.58      0.30      0.39       480
#
# avg / total       0.92      0.93      0.92      6554
#
# Accuracy of              medical_help: 1.00
# Category: medical_products
#               precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      6220
#           1       0.62      0.30      0.40       334
#
# avg / total       0.95      0.96      0.95      6554
#
# Accuracy of          medical_products: 1.00
# Category: search_and_rescue
#               precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6393
#           1       0.55      0.21      0.30       161
#
# avg / total       0.97      0.98      0.97      6554
#
# Accuracy of         search_and_rescue: 1.00
# Category: security
#               precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6424
#           1       0.50      0.05      0.08       130
#
# avg / total       0.97      0.98      0.97      6554
#
# Accuracy of                  security: 1.00
# Category: military
#               precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      6346
#           1       0.55      0.35      0.43       208
#
# avg / total       0.97      0.97      0.97      6554
#
# Accuracy of                  military: 1.00
# Category: child_alone
#               precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# Accuracy of               child_alone: 1.00
# Category: water
#               precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      6168
#           1       0.75      0.63      0.68       386
#
# avg / total       0.96      0.97      0.96      6554
#
# Accuracy of                     water: 1.00
# Category: food
#               precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97      5842
#           1       0.80      0.63      0.71       712
#
# avg / total       0.94      0.94      0.94      6554
#
# Accuracy of                      food: 1.00
# Category: shelter
#               precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      5990
#           1       0.77      0.50      0.60       564
#
# avg / total       0.94      0.94      0.94      6554
#
# Accuracy of                   shelter: 1.00
# Category: clothing
#               precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6457
#           1       0.76      0.39      0.52        97
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy of                  clothing: 1.00
# Category: money
#               precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6412
#           1       0.66      0.31      0.42       142
#
# avg / total       0.98      0.98      0.98      6554
#
# Accuracy of                     money: 1.00
# Category: missing_people
#               precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6463
#           1       0.56      0.15      0.24        91
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy of            missing_people: 1.00
# Category: refugees
#               precision    recall  f1-score   support
#
#           0       0.98      0.99      0.99      6356
#           1       0.55      0.24      0.34       198
#
# avg / total       0.96      0.97      0.97      6554
#
# Accuracy of                  refugees: 1.00
# Category: death
#               precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      6263
#           1       0.68      0.43      0.53       291
#
# avg / total       0.96      0.97      0.96      6554
#
# Accuracy of                     death: 1.00
# Category: other_aid
#               precision    recall  f1-score   support
#
#           0       0.88      0.98      0.93      5689
#           1       0.50      0.13      0.21       865
#
# avg / total       0.83      0.87      0.83      6554
#
# Accuracy of                 other_aid: 1.00
# Category: infrastructure_related
#               precision    recall  f1-score   support
#
#           0       0.94      0.99      0.97      6138
#           1       0.47      0.09      0.15       416
#
# avg / total       0.91      0.94      0.92      6554
#
# Accuracy of    infrastructure_related: 1.00
# Category: transport
#               precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      6271
#           1       0.61      0.28      0.39       283
#
# avg / total       0.95      0.96      0.95      6554
#
# Accuracy of                 transport: 1.00
# Category: buildings
#               precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      6229
#           1       0.70      0.36      0.48       325
#
# avg / total       0.95      0.96      0.95      6554
#
# Accuracy of                 buildings: 1.00
# Category: electricity
#               precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6431
#           1       0.48      0.20      0.29       123
#
# avg / total       0.98      0.98      0.98      6554
#
# Accuracy of               electricity: 1.00
# Category: tools
#               precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6512
#           1       0.00      0.00      0.00        42
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy of                     tools: 1.00
# Category: hospitals
#               precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6484
#           1       0.19      0.04      0.07        70
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy of                 hospitals: 1.00
# Category: shops
#               precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6528
#           1       0.00      0.00      0.00        26
#
# avg / total       0.99      1.00      0.99      6554
#
# Accuracy of                     shops: 1.00
# Category: aid_centers
#               precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6473
#           1       0.38      0.12      0.19        81
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy of               aid_centers: 1.00
# Category: other_infrastructure
#               precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      6275
#           1       0.21      0.05      0.08       279
#
# avg / total       0.93      0.95      0.94      6554
#
# Accuracy of      other_infrastructure: 1.00
# Category: weather_related
#               precision    recall  f1-score   support
#
#           0       0.88      0.96      0.92      4697
#           1       0.88      0.65      0.75      1857
#
# avg / total       0.88      0.88      0.87      6554
#
# Accuracy of           weather_related: 1.00
# Category: floods
#               precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      6011
#           1       0.87      0.58      0.70       543
#
# avg / total       0.96      0.96      0.95      6554
#
# Accuracy of                    floods: 1.00
# Category: storm
#               precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      5932
#           1       0.77      0.45      0.57       622
#
# avg / total       0.93      0.94      0.93      6554
#
# Accuracy of                     storm: 1.00
# Category: fire
#               precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6496
#           1       0.48      0.17      0.25        58
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy of                      fire: 1.00
# Category: earthquake
#               precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      5905
#           1       0.92      0.79      0.85       649
#
# avg / total       0.97      0.97      0.97      6554
#
# Accuracy of                earthquake: 1.00
# Category: cold
#               precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6417
#           1       0.81      0.34      0.48       137
#
# avg / total       0.98      0.98      0.98      6554
#
# Accuracy of                      cold: 1.00
# Category: other_weather
#               precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      6213
#           1       0.48      0.13      0.20       341
#
# avg / total       0.93      0.95      0.93      6554
#
# Accuracy of             other_weather: 1.00
# Category: direct_report
#               precision    recall  f1-score   support
#
#           0       0.87      0.96      0.91      5251
#           1       0.71      0.44      0.54      1303
#
# avg / total       0.84      0.85      0.84      6554
#
# Accuracy of             direct_report: 1.00

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
pickle.dump(model, open(model_filepath, "wb"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-231d16162422> in <module>()
# ----> 1 pickle.dump(model, open(model_filepath, "wb"))
#
# NameError: name 'model' is not defined

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
